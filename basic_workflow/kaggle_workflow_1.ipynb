# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#             color: white;
#             padding: 18px;
#             border-radius: 15px;
#             font-size: 18px;
#             text-align: center;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.2);">
#
#   🚀 <b>Its test only to know its posible to create a workflow AI file structure in kaggle or not</b> 🚀
#
# </div>

# %%
import os
from pathlib import Path
import sys
from importlib import import_module, reload
sys.path.append('/kaggle/working/src')

# !mkdir -p src

# %%
def import_or_reload(module_name, path="/kaggle/working/src"):
    """
    Import a module from given path. 
    If already imported, reload it so changes apply.
    """
    if path not in sys.path:
        sys.path.append(path)
    
    if module_name in sys.modules:
        return reload(sys.modules[module_name])
    else:
        return import_module(module_name)

# %%
# %%writefile src/data_cleaning.py
import pandas as pd

def read_data(path='/kaggle/input/iris/Iris.csv'):
    df = pd.read_csv(path)
    return df
# Out:
# Overwriting src/data_cleaning.py

# %%
import_or_reload('data_cleaning')
# Out:
# <module 'data_cleaning' from '/kaggle/working/src/data_cleaning.py'>

# %%
data_cleaning.read_data()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# <div style="background: linear-gradient(135deg, #56ab2f 0%, #a8e063 100%);
#             color: #1f2937;
#             padding: 18px;
#             border-radius: 15px;
#             font-size: 18px;
#             text-align: center;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.2);">
#
#   🎉 <b>Yes! It’s possible 🚀
#   You can structure your Kaggle project like a real AI workflow.</b> 🎉
#   <br><br>
#   ⭐ Don’t forget to <b>Star</b> and <b>Upvote</b> if this helped ⭐
# </div>

# %% [markdown]
# <a href="https://www.kaggle.com/code/aicortex/kaggle-workflow-2?scriptVersionId=259854059" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #56ab2f 0%, #a8e063 100%);
#             color: #1f2937;
#             padding: 18px;
#             border-radius: 15px;
#             font-size: 18px;
#             text-align: center;
#             font-weight: bold;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.2);">
#
#   🌟 <b>This is only a test to check if building a workflow AI file structure in Kaggle is possible</b> 🌟
#
# </div>

# %%
import sys
sys.path.append("/kaggle/input/test-1-utility-script")

# %%
import create_data
import split_data

# %%
X, y = create_data.data_creator()
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X_trian, X_test, y_train, y_test = split_data.spliter(X, y)
X_trian.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 2), (200, 2), (800,), (200,))

# %% [markdown]
# <div style="text-align:center; margin:20px;
#      text-decoration:none; padding:10px 16px; border-radius:12px;
#             background:#22c55e; color:#0b1a13; font-weight:700;
#             border:1px solid rgba(34,197,94,.6);">
#     ⭐ Upvote ⭐
# </div>

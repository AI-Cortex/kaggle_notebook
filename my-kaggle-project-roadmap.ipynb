# %% [markdown]
# <a href="https://www.kaggle.com/code/aicortex/my-kaggle-project-roadmap?scriptVersionId=262651762" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #667eea, #764ba2);
#             color: white;
#             padding: 20px;
#             border-radius: 15px;
#             text-align: center;
#             font-size: 22px;
#             font-weight: bold;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.3);">
#   🚀 My Kaggle Project Roadmap 🚀
# </div>
#
# ---
#
# 📅 **Last Update:** 2025-09-02
#
# *planned*  *in progress*   *waiting*  *completed*
# ---
#
# ## 📌 Current Tasks
# - [ ] create kaggle_workflow_3 use github  — *planned **2025-09-03***
# - [ ] create categorical classification Utility_Script for `pytorch` and `tensorflow` *planned **2025-09-18***
# -
# ---
#
# ## ✅ Completed Tasks
# - [x] create [Binary classification Utility_Script](https://www.kaggle.com/datasets/aicortex/binary-classification) for `pytorch` and `tensorflow` [*planned **2025-09-03***] - [*completed **2025-09-18***]
#     - *Note: This task still requires improvements. For ongoing updates, please check the project page.*
#     - .
# - [x] create [regression Utility_Script](https://www.kaggle.com/datasets/aicortex/regression-utility-script) for `pytorch` and `tensorflow` [*planned **2025-09-03***] [*completed **2025-09-18***]
#     - *Note: This task still requires improvements. For ongoing updates, please check the project page.*
#     - .
#
# - [x] create kaggle_workflow_1  — [*planned **2025-09-02***] — [*completed **2025-09-02***]
#     - implemented `import_or_reload` helper
#     - added `data_cleaning.read_data()` function
#
# - [x] create kaggle_workflow_2  — [*planned **2025-09-02***] — [*completed **2025-09-03***]
#     - created utility scripts: `create_data` and `split_data`
#     - published as Dataset: [test-1-utility-script](https://www.kaggle.com/datasets/aicortex/test-1-utility-script)
#     - tested data creation and splitting → verified shapes
#
# - [x]
#
# ---
#
# ## 💡 Future Ideas
# -  basic pytorch learning notebooks *2025-09-02* *in progress*
# -  basic tensorflow learning notebooks *2025-09-02* *in progress*
# -
#
#
# ---
#
# <div style="background: linear-gradient(135deg, #56ab2f, #a8e063);
#             color: #1f2937;
#             padding: 18px;
#             border-radius: 15px;
#             font-size: 18px;
#             text-align: center;
#             box-shadow: 0 4px 10px rgba(0,0,0,0.2);">
#   ⭐ If you like this project, don’t forget to Upvote</b> ⭐
# </div>

# %%
from datetime import datetime

now = datetime.now().strftime("%Y-%m-%d")

print(now)
# Out:
# 2025-09-18
